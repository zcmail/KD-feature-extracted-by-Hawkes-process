# %%
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
from pandas import DataFrame
import pandas as pd
import seaborn as sns
import numpy as np
import json
import os
import tensorflow as tf

np.set_printoptions(threshold=np.inf)

fileName1 = './data/CMU_exp_shrink_output_rep50.xls'
df_ora1 = pd.read_excel(fileName1)

#fileName2 = './data/CMU_oral_output.xls'
#df_ora2 = pd.read_excel(fileName2)

#df_ora = pd.merge(df_ora1,df_ora2,on = 'key')
df_ora = df_ora1

#object_user = 's002'
object_user = 's032'
#object_user = 's036'
#object_user = 's047'
#object_user = 's052'

df_ora.loc[df_ora['user']!=object_user,'user'] = 'imposter'
df = df_ora
#df = df_ora.loc[(df_ora['user']==object_user) | (df_ora['session']<400)]

#print (df) 
###################################PCA
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler,LabelEncoder,LabelEncoder

le = LabelEncoder()
df['target'] = le.fit_transform(df['user'])
df.drop(['user'], axis=1, inplace=True)

X = df.drop(['target','session','key','adj29'], axis=1)  #去掉激励核的最后一个值（对区分贡献不大）

for _,colums in enumerate(X.columns):
    X.loc[X[colums]<0.1,colums]=0.0
    #print(colums)

y = df['target'].values

ss = StandardScaler()
X = ss.fit_transform(X)
X = pd.DataFrame(X)

# %%
'''
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.3, random_state=19, shuffle=True)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
'''
'''
#s002
index_train1 = [i for i in range(200)]    #s002
index_train2 = [i+400 for i in range(50)] #s032
index_train3 = [i+800 for i in range(50)] #s036
index_train4 = [i+1200 for i in range(50)] #s047
index_train5 = [i+1600 for i in range(50)] #s052

index_test1 = [i+200 for i in range(200)] #s002
index_test2 = [i+450 for i in range(350)]  #s032
index_test3 = [i+850 for i in range(350)]  #s036
index_test4 = [i+1250 for i in range(350)]  #s047
index_test5 = [i+1650 for i in range(350)]  #s052
'''

#s032
index_train1 = [i+400 for i in range(200)] #s032
index_train2 = [i for i in range(50)] #s002
index_train3 = [i+800 for i in range(50)] #s036
index_train4 = [i+1200 for i in range(50)] #s047
index_train5 = [i+1600 for i in range(50)] #s052

index_test1 = [i+600 for i in range(200)] #s032
index_test2 = [i+50 for i in range(350)]  #s002
index_test3 = [i+850 for i in range(350)]  #s036
index_test4 = [i+1250 for i in range(350)]  #s047
index_test5 = [i+1650 for i in range(350)]  #s052


'''
#s036
index_train1 = [i+200 for i in range(200)] #s036
index_train2 = [i for i in range(50)] #s002
index_train3 = [i+100 for i in range(50)] #s032
index_train4 = [i+600 for i in range(50)] #s047
index_train5 = [i+700 for i in range(50)] #s052

index_test1 = [i+400 for i in range(200)] #s036
index_test2 = [i+50 for i in range(50)]  #s002
index_test3 = [i+150 for i in range(50)]  #s032
index_test4 = [i+650 for i in range(50)]  #s047
index_test5 = [i+750 for i in range(50)]  #s052
'''

'''
#s047
index_train1 = [i+300 for i in range(200)] #s047
index_train2 = [i for i in range(50)] #s002
index_train3 = [i+100 for i in range(50)] #s032
index_train4 = [i+200 for i in range(50)] #s036
index_train5 = [i+700 for i in range(50)] #s052

index_test1 = [i+500 for i in range(200)] #s047
index_test2 = [i+50 for i in range(50)]  #s002
index_test3 = [i+150 for i in range(50)]  #s032
index_test4 = [i+250 for i in range(50)]  #s036
index_test5 = [i+750 for i in range(50)]  #s052
'''
'''
#s052
index_train1 = [i+400 for i in range(200)] #s052
index_train2 = [i for i in range(50)] #s002
index_train3 = [i+100 for i in range(50)] #s032
index_train4 = [i+200 for i in range(50)] #s036
index_train5 = [i+300 for i in range(50)] #s047

index_test1 = [i+600 for i in range(200)] #s052
index_test2 = [i+50 for i in range(50)]  #s002
index_test3 = [i+150 for i in range(50)]  #s032
index_test4 = [i+250 for i in range(50)]  #s036
index_test5 = [i+350 for i in range(50)]  #s047
'''

index_train = index_train1 + index_train2 + index_train3 + index_train4 + index_train5
index_test = index_test1 + index_test2 + index_test3 + index_test4 + index_test5

X_train = X.iloc[index_train]
X_test = X.iloc[index_test]
y_train = y[index_train]
y_test = y[index_test]

# %% [markdown]
# 度量选择（AUC）

# %% [markdown]
# SVM2

# %%
from numpy.random import seed
seed(1)
tf.random.set_seed(2)

import numpy as np
import sklearn.model_selection as ms
import sklearn.svm as svm
import sklearn.metrics as sm
import matplotlib.pyplot as plt

# 最优超参数组合列表
params = [
        {'kernel': ['linear'], 'C': [1, 10, 100, 1000]},
        {'kernel': ['poly'], 'C': [1,10,100], 'degree': [2, 3]},
        {'kernel': ['rbf'], 'C': [1, 10, 100, 100,1000], 'gamma':[1, 0.1, 0.01, 0.001]}
        ]

model = ms.GridSearchCV(svm.SVC(probability=True), 
                        params, 
                        refit=True,
                        return_train_score=True,        # 后续版本需要指定True才有score方法  
                        cv=4)
model.fit(X_train, y_train)

# GridSearchCV的属性
print('Attrabutes:vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv')
print('cv_results_:',model.cv_results_.keys())
print('Desc:',model.cv_results_['params'][2], model.cv_results_['mean_train_score'][2], 
      model.cv_results_['mean_test_score'][2],model.cv_results_['rank_test_score'][2])
print('best_estimator_:',model.best_estimator_) 
print('best_params_:',model.best_params_) 
print('best_params_:', model.cv_results_['params'][model.best_index_])
print('best_score_:',model.best_score_)
print('scorer_:',model.scorer_)
print('n_splits_:',model.n_splits_)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# Attrabutes:vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# cv_results_: dict_keys(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time', 'param_C', 'param_kernel', 'param_degree', 'param_gamma', 'params', 'split0_test_score', 'split1_test_score', 'split2_test_score', 'split3_test_score', 'mean_test_score', 'std_test_score', 'rank_test_score', 'split0_train_score', 'split1_train_score', 'split2_train_score', 'split3_train_score', 'mean_train_score', 'std_train_score'])
# Desc: {'C': 100, 'kernel': 'linear'} 0.9683333333333333 0.7925 25
# best_estimator_: SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# best_params_: {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# best_params_: {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# best_score_: 0.9225
# scorer_: <function _passthrough_scorer at 0x7f2b337df950>
# n_splits_: 4

# %%
y_predict_SVM = model.best_estimator_.predict(X_test)
#y_predict_SVM
ann_fileName = "SVM_best"+object_user+"_Hawkes_pred_final_rep50.txt"
np.savetxt(ann_fileName, np.array(y_predict_SVM))

# %%
#评价指标
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score,accuracy_score

y_true = np.reshape(y_test, [-1])
y_pred = np.reshape(y_predict_SVM, [-1])
  
# 评价指标
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred, average='binary')
f1score = f1_score(y_true, y_pred, average='binary')
  
# Micro F1: 将n分类的评价拆成n个二分类的评价，将n个二分类评价的TP、FP、RN对应相加，计算评价准确率和召回率，由这2个准确率和召回率计算的F1 score即为Micro F1。
# Macro F1: 将n分类的评价拆成n个二分类的评价，计算每个二分类的F1 score，n个F1 score的平均值即为Macro F1。
# 一般来讲，Macro F1、Micro F1高的分类效果好。Macro F1受样本数量少的类别影响大。
micro_f1 = f1_score(y_true, y_pred,average='micro')
macro_f1 = f1_score(y_true, y_pred,average='macro')
  
print('accuracy:',accuracy)
print('precision:',precision)
print('recall:',recall)
print('f1score:',f1score)
print('Macro-F1: {}'.format(macro_f1))
print('Micro-F1: {}'.format(micro_f1))
# Out:
# accuracy: 0.62875
# precision: 0.24281984334203655
# recall: 0.93
# f1score: 0.3850931677018633
# Macro-F1: 0.5596011944149424
# Micro-F1: 0.62875

# %% [markdown]
# 神经网络

# %%
from numpy.random import seed
seed(1)
tf.random.set_seed(2)

from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV
import numpy as np
import pickle
import gzip
import matplotlib.pyplot as plt

mlp_clf__tuned_parameters = {"hidden_layer_sizes": [(40),(40,16),(50,),(50,32),(64), (64,32),(128,64,32)],
                             "solver": ['adam', 'sgd', 'lbfgs'],
                             "max_iter": [20,100,200,1000,5000],
                             "verbose": [True]
                             }
mlp = MLPClassifier()
estimator = GridSearchCV(mlp, mlp_clf__tuned_parameters, n_jobs=6)
estimator.fit(X_train, y_train)

print(estimator.get_params().keys()) 
print (estimator.best_params_)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Iteration 1, loss = 0.81908542
# Iteration 2, loss = 0.81168548
# Iteration 3, loss = 0.80071580
# Iteration 4, loss = 0.78684598
# Iteration 5, loss = 0.77112436
# Iteration 6, loss = 0.75443245
# Iteration 7, loss = 0.73653394
# Iteration 8, loss = 0.71819374
# Iteration 9, loss = 0.70053674
# Iteration 10, loss = 0.68172074
# Iteration 11, loss = 0.66425310
# Iteration 12, loss = 0.64689793
# Iteration 13, loss = 0.63037354
# Iteration 14, loss = 0.61478435
# Iteration 15, loss = 0.59956223
# Iteration 16, loss = 0.58494956
# Iteration 17, loss = 0.57088975
# Iteration 18, loss = 0.55788146
# Iteration 19, loss = 0.54541128
# Iteration 20, loss = 0.53339370
# Iteration 21, loss = 0.52200301
# Iteration 22, loss = 0.51143685
# Iteration 23, loss = 0.50130503
# Iteration 24, loss = 0.49189365
# Iteration 25, loss = 0.48278933
# Iteration 26, loss = 0.47432227
# Iteration 27, loss = 0.46614934
# Iteration 28, loss = 0.45826920
# Iteration 29, loss = 0.45067944
# Iteration 30, loss = 0.44383202
# Iteration 31, loss = 0.43690809
# Iteration 32, loss = 0.43062116
# Iteration 33, loss = 0.42457930
# Iteration 34, loss = 0.41864863
# Iteration 35, loss = 0.41290114
# Iteration 36, loss = 0.40738717
# Iteration 37, loss = 0.40232796
# Iteration 38, loss = 0.39732919
# Iteration 39, loss = 0.39257926
# Iteration 40, loss = 0.38800864
# Iteration 41, loss = 0.38357953
# Iteration 42, loss = 0.37936548
# Iteration 43, loss = 0.37512243
# Iteration 44, loss = 0.37113455
# Iteration 45, loss = 0.36731494
# Iteration 46, loss = 0.36353268
# Iteration 47, loss = 0.36016100
# Iteration 48, loss = 0.35664107
# Iteration 49, loss = 0.35341340
# Iteration 50, loss = 0.35016048
# Iteration 51, loss = 0.34701523
# Iteration 52, loss = 0.34406159
# Iteration 53, loss = 0.34107116
# Iteration 54, loss = 0.33832641
# Iteration 55, loss = 0.33548056
# Iteration 56, loss = 0.33287753
# Iteration 57, loss = 0.33026584
# Iteration 58, loss = 0.32771793
# Iteration 59, loss = 0.32530127
# Iteration 60, loss = 0.32300745
# Iteration 61, loss = 0.32073946
# Iteration 62, loss = 0.31847117
# Iteration 63, loss = 0.31635726
# Iteration 64, loss = 0.31423246
# Iteration 65, loss = 0.31207923
# Iteration 66, loss = 0.31015576
# Iteration 67, loss = 0.30821013
# Iteration 68, loss = 0.30622611
# Iteration 69, loss = 0.30440810
# Iteration 70, loss = 0.30259228
# Iteration 71, loss = 0.30087843
# Iteration 72, loss = 0.29906215
# Iteration 73, loss = 0.29738603
# Iteration 74, loss = 0.29577272
# Iteration 75, loss = 0.29411798
# Iteration 76, loss = 0.29252714
# Iteration 77, loss = 0.29103217
# Iteration 78, loss = 0.28946620
# Iteration 79, loss = 0.28805765
# Iteration 80, loss = 0.28662942
# Iteration 81, loss = 0.28517476
# Iteration 82, loss = 0.28383945
# Iteration 83, loss = 0.28249868
# Iteration 84, loss = 0.28118560
# Iteration 85, loss = 0.27988237
# Iteration 86, loss = 0.27861416
# Iteration 87, loss = 0.27738392
# Iteration 88, loss = 0.27617202
# Iteration 89, loss = 0.27498189
# Iteration 90, loss = 0.27383042
# Iteration 91, loss = 0.27269440
# Iteration 92, loss = 0.27157443
# Iteration 93, loss = 0.27051428
# Iteration 94, loss = 0.26940568
# Iteration 95, loss = 0.26836359
# Iteration 96, loss = 0.26733097
# Iteration 97, loss = 0.26631992
# Iteration 98, loss = 0.26533947
# Iteration 99, loss = 0.26435647
# Iteration 100, loss = 0.26337000
# Iteration 101, loss = 0.26246479
# Iteration 102, loss = 0.26153078
# Iteration 103, loss = 0.26064376
# Iteration 104, loss = 0.25969160
# Iteration 105, loss = 0.25882236
# Iteration 106, loss = 0.25797194
# Iteration 107, loss = 0.25715241
# Iteration 108, loss = 0.25628333
# Iteration 109, loss = 0.25546965
# Iteration 110, loss = 0.25463363
# Iteration 111, loss = 0.25387071
# Iteration 112, loss = 0.25306820
# Iteration 113, loss = 0.25228729
# Iteration 114, loss = 0.25154343
# Iteration 115, loss = 0.25077420
# Iteration 116, loss = 0.25004027
# Iteration 117, loss = 0.24932863
# Iteration 118, loss = 0.24861516
# Iteration 119, loss = 0.24792214
# Iteration 120, loss = 0.24720664
# Iteration 121, loss = 0.24653107
# Iteration 122, loss = 0.24583299
# Iteration 123, loss = 0.24519056
# Iteration 124, loss = 0.24455742
# Iteration 125, loss = 0.24388938
# Iteration 126, loss = 0.24324364
# Iteration 127, loss = 0.24262551
# Iteration 128, loss = 0.24203421
# Iteration 129, loss = 0.24140105
# Iteration 130, loss = 0.24079123
# Iteration 131, loss = 0.24020120
# Iteration 132, loss = 0.23962375
# Iteration 133, loss = 0.23904445
# Iteration 134, loss = 0.23847074
# Iteration 135, loss = 0.23792345
# Iteration 136, loss = 0.23733870
# Iteration 137, loss = 0.23679201
# Iteration 138, loss = 0.23625608
# Iteration 139, loss = 0.23571858
# Iteration 140, loss = 0.23519153
# Iteration 141, loss = 0.23467039
# Iteration 142, loss = 0.23413411
# Iteration 143, loss = 0.23362665
# Iteration 144, loss = 0.23315019
# Iteration 145, loss = 0.23261935
# Iteration 146, loss = 0.23213863
# Iteration 147, loss = 0.23165771
# Iteration 148, loss = 0.23116950
# Iteration 149, loss = 0.23066790
# Iteration 150, loss = 0.23023925
# Iteration 151, loss = 0.22974785
# Iteration 152, loss = 0.22928781
# Iteration 153, loss = 0.22883951
# Iteration 154, loss = 0.22836799
# Iteration 155, loss = 0.22794202
# Iteration 156, loss = 0.22749848
# Iteration 157, loss = 0.22706567
# Iteration 158, loss = 0.22661123
# Iteration 159, loss = 0.22621035
# Iteration 160, loss = 0.22575895
# Iteration 161, loss = 0.22536046
# Iteration 162, loss = 0.22493908
# Iteration 163, loss = 0.22453206
# Iteration 164, loss = 0.22413174
# Iteration 165, loss = 0.22373318
# Iteration 166, loss = 0.22333280
# Iteration 167, loss = 0.22292212
# Iteration 168, loss = 0.22254566
# Iteration 169, loss = 0.22215434
# Iteration 170, loss = 0.22177501
# Iteration 171, loss = 0.22137965
# Iteration 172, loss = 0.22101160
# Iteration 173, loss = 0.22065990
# Iteration 174, loss = 0.22026662
# Iteration 175, loss = 0.21991043
# Iteration 176, loss = 0.21955328
# Iteration 177, loss = 0.21918464
# Iteration 178, loss = 0.21882893
# Iteration 179, loss = 0.21850081
# Iteration 180, loss = 0.21813568
# Iteration 181, loss = 0.21778308
# Iteration 182, loss = 0.21744656
# Iteration 183, loss = 0.21710882
# Iteration 184, loss = 0.21677997
# Iteration 185, loss = 0.21645252
# Iteration 186, loss = 0.21611555
# Iteration 187, loss = 0.21578958
# Iteration 188, loss = 0.21545151
# Iteration 189, loss = 0.21513501
# Iteration 190, loss = 0.21481136
# Iteration 191, loss = 0.21450107
# Iteration 192, loss = 0.21418662
# Iteration 193, loss = 0.21386939
# Iteration 194, loss = 0.21356172
# Iteration 195, loss = 0.21324813
# Iteration 196, loss = 0.21293265
# Iteration 197, loss = 0.21264146
# Iteration 198, loss = 0.21234204
# Iteration 199, loss = 0.21205035
# Iteration 200, loss = 0.21175046
# Iteration 201, loss = 0.21145040
# Iteration 202, loss = 0.21116361
# Iteration 203, loss = 0.21088152
# Iteration 204, loss = 0.21059838
# Iteration 205, loss = 0.21030778
# Iteration 206, loss = 0.21002264
# Iteration 207, loss = 0.20974332
# Iteration 208, loss = 0.20946811
# Iteration 209, loss = 0.20920596
# Iteration 210, loss = 0.20891882
# Iteration 211, loss = 0.20865139
# Iteration 212, loss = 0.20837746
# Iteration 213, loss = 0.20810675
# Iteration 214, loss = 0.20785896
# Iteration 215, loss = 0.20758963
# Iteration 216, loss = 0.20731803
# Iteration 217, loss = 0.20707105
# Iteration 218, loss = 0.20679843
# Iteration 219, loss = 0.20653605
# Iteration 220, loss = 0.20629333
# Iteration 221, loss = 0.20603616
# Iteration 222, loss = 0.20578191
# Iteration 223, loss = 0.20554224
# Iteration 224, loss = 0.20529899
# Iteration 225, loss = 0.20504583
# Iteration 226, loss = 0.20479721
# Iteration 227, loss = 0.20456437
# Iteration 228, loss = 0.20433920
# Iteration 229, loss = 0.20408587
# Iteration 230, loss = 0.20385534
# Iteration 231, loss = 0.20361181
# Iteration 232, loss = 0.20337480
# Iteration 233, loss = 0.20315335
# Iteration 234, loss = 0.20292073
# Iteration 235, loss = 0.20268354
# Iteration 236, loss = 0.20246033
# Iteration 237, loss = 0.20223225
# Iteration 238, loss = 0.20201244
# Iteration 239, loss = 0.20177977
# Iteration 240, loss = 0.20156224
# Iteration 241, loss = 0.20133578
# Iteration 242, loss = 0.20112663
# Iteration 243, loss = 0.20090404
# Iteration 244, loss = 0.20068701
# Iteration 245, loss = 0.20047578
# Iteration 246, loss = 0.20025872
# Iteration 247, loss = 0.20005335
# Iteration 248, loss = 0.19982286
# Iteration 249, loss = 0.19962267
# Iteration 250, loss = 0.19940942
# Iteration 251, loss = 0.19919955
# Iteration 252, loss = 0.19899294
# Iteration 253, loss = 0.19879771
# Iteration 254, loss = 0.19859261
# Iteration 255, loss = 0.19838667
# Iteration 256, loss = 0.19817257
# Iteration 257, loss = 0.19798066
# Iteration 258, loss = 0.19777124
# Iteration 259, loss = 0.19757667
# Iteration 260, loss = 0.19739735
# Iteration 261, loss = 0.19717296
# Iteration 262, loss = 0.19698908
# Iteration 263, loss = 0.19680012
# Iteration 264, loss = 0.19659974
# Iteration 265, loss = 0.19641283
# Iteration 266, loss = 0.19621393
# Iteration 267, loss = 0.19602981
# Iteration 268, loss = 0.19583869
# Iteration 269, loss = 0.19565246
# Iteration 270, loss = 0.19546529
# Iteration 271, loss = 0.19528400
# Iteration 272, loss = 0.19509592
# Iteration 273, loss = 0.19490364
# Iteration 274, loss = 0.19472510
# Iteration 275, loss = 0.19454044
# Iteration 276, loss = 0.19436000
# Iteration 277, loss = 0.19418183
# Iteration 278, loss = 0.19400319
# Iteration 279, loss = 0.19382749
# Iteration 280, loss = 0.19365151
# Iteration 281, loss = 0.19347324
# Iteration 282, loss = 0.19330012
# Iteration 283, loss = 0.19313362
# Iteration 284, loss = 0.19294872
# Iteration 285, loss = 0.19278330
# Iteration 286, loss = 0.19260403
# Iteration 287, loss = 0.19243987
# Iteration 288, loss = 0.19226164
# Iteration 289, loss = 0.19210200
# Iteration 290, loss = 0.19192799
# Iteration 291, loss = 0.19176043
# Iteration 292, loss = 0.19159344
# Iteration 293, loss = 0.19142948
# Iteration 294, loss = 0.19127679
# Iteration 295, loss = 0.19109615
# Iteration 296, loss = 0.19093938
# Iteration 297, loss = 0.19076989
# Iteration 298, loss = 0.19060927
# Iteration 299, loss = 0.19044363
# Iteration 300, loss = 0.19028829
# Iteration 301, loss = 0.19012807
# Iteration 302, loss = 0.18997714
# Iteration 303, loss = 0.18980842
# Iteration 304, loss = 0.18965197
# Iteration 305, loss = 0.18949366
# Iteration 306, loss = 0.18933741
# Iteration 307, loss = 0.18917575
# Iteration 308, loss = 0.18902475
# Iteration 309, loss = 0.18886763
# Iteration 310, loss = 0.18871796
# Iteration 311, loss = 0.18856501
# Iteration 312, loss = 0.18840287
# Iteration 313, loss = 0.18825445
# Iteration 314, loss = 0.18810820
# Iteration 315, loss = 0.18795605
# Iteration 316, loss = 0.18780299
# Iteration 317, loss = 0.18765701
# Iteration 318, loss = 0.18750566
# Iteration 319, loss = 0.18735992
# Iteration 320, loss = 0.18720833
# Iteration 321, loss = 0.18706439
# Iteration 322, loss = 0.18691659
# Iteration 323, loss = 0.18677326
# Iteration 324, loss = 0.18662458
# Iteration 325, loss = 0.18647862
# Iteration 326, loss = 0.18633441
# Iteration 327, loss = 0.18619217
# Iteration 328, loss = 0.18605682
# Iteration 329, loss = 0.18590618
# Iteration 330, loss = 0.18576869
# Iteration 331, loss = 0.18562847
# Iteration 332, loss = 0.18549567
# Iteration 333, loss = 0.18534500
# Iteration 334, loss = 0.18520510
# Iteration 335, loss = 0.18507105
# Iteration 336, loss = 0.18492996
# Iteration 337, loss = 0.18479119
# Iteration 338, loss = 0.18465370
# Iteration 339, loss = 0.18451616
# Iteration 340, loss = 0.18437338
# Iteration 341, loss = 0.18424018
# Iteration 342, loss = 0.18410368
# Iteration 343, loss = 0.18397370
# Iteration 344, loss = 0.18383418
# Iteration 345, loss = 0.18369587
# Iteration 346, loss = 0.18356838
# Iteration 347, loss = 0.18343415
# Iteration 348, loss = 0.18330021
# Iteration 349, loss = 0.18316911
# Iteration 350, loss = 0.18303228
# Iteration 351, loss = 0.18289775
# Iteration 352, loss = 0.18276890
# Iteration 353, loss = 0.18263978
# Iteration 354, loss = 0.18250670
# Iteration 355, loss = 0.18238047
# Iteration 356, loss = 0.18224606
# Iteration 357, loss = 0.18211344
# Iteration 358, loss = 0.18198964
# Iteration 359, loss = 0.18186171
# Iteration 360, loss = 0.18173036
# Iteration 361, loss = 0.18160681
# Iteration 362, loss = 0.18148439
# Iteration 363, loss = 0.18135107
# Iteration 364, loss = 0.18122308
# Iteration 365, loss = 0.18110438
# Iteration 366, loss = 0.18097116
# Iteration 367, loss = 0.18084805
# Iteration 368, loss = 0.18071913
# Iteration 369, loss = 0.18059875
# Iteration 370, loss = 0.18047552
# Iteration 371, loss = 0.18034898
# Iteration 372, loss = 0.18022690
# Iteration 373, loss = 0.18010438
# Iteration 374, loss = 0.17998822
# Iteration 375, loss = 0.17986250
# Iteration 376, loss = 0.17974786
# Iteration 377, loss = 0.17962469
# Iteration 378, loss = 0.17950338
# Iteration 379, loss = 0.17938385
# Iteration 380, loss = 0.17926740
# Iteration 381, loss = 0.17913966
# Iteration 382, loss = 0.17902531
# Iteration 383, loss = 0.17890915
# Iteration 384, loss = 0.17879067
# Iteration 385, loss = 0.17867344
# Iteration 386, loss = 0.17856481
# Iteration 387, loss = 0.17844257
# Iteration 388, loss = 0.17832314
# Iteration 389, loss = 0.17821524
# Iteration 390, loss = 0.17809546
# Iteration 391, loss = 0.17798012
# Iteration 392, loss = 0.17787550
# Iteration 393, loss = 0.17775110
# Iteration 394, loss = 0.17763958
# Iteration 395, loss = 0.17753708
# Iteration 396, loss = 0.17741872
# Iteration 397, loss = 0.17730778
# Iteration 398, loss = 0.17719706
# Iteration 399, loss = 0.17707970
# Iteration 400, loss = 0.17697572
# Iteration 401, loss = 0.17686532
# Iteration 402, loss = 0.17675084
# Iteration 403, loss = 0.17664490
# Iteration 404, loss = 0.17654283
# Iteration 405, loss = 0.17642579
# Iteration 406, loss = 0.17631782
# Iteration 407, loss = 0.17621315
# Iteration 408, loss = 0.17610391
# Iteration 409, loss = 0.17599643
# Iteration 410, loss = 0.17589427
# Iteration 411, loss = 0.17578715
# Iteration 412, loss = 0.17567887
# Iteration 413, loss = 0.17557060
# Iteration 414, loss = 0.17546898
# Iteration 415, loss = 0.17537157
# Iteration 416, loss = 0.17526363
# Iteration 417, loss = 0.17515139
# Iteration 418, loss = 0.17505041
# Iteration 419, loss = 0.17495073
# Iteration 420, loss = 0.17484990
# Iteration 421, loss = 0.17474789
# Iteration 422, loss = 0.17464982
# Iteration 423, loss = 0.17453650
# Iteration 424, loss = 0.17444300
# Iteration 425, loss = 0.17434815
# Iteration 426, loss = 0.17425068
# Iteration 427, loss = 0.17415183
# Iteration 428, loss = 0.17404367
# Iteration 429, loss = 0.17394464
# Iteration 430, loss = 0.17384480
# Iteration 431, loss = 0.17374426
# Iteration 432, loss = 0.17364981
# Iteration 433, loss = 0.17355142
# Iteration 434, loss = 0.17345267
# Iteration 435, loss = 0.17335324
# Iteration 436, loss = 0.17325812
# Iteration 437, loss = 0.17316177
# Iteration 438, loss = 0.17306409
# Iteration 439, loss = 0.17296881
# Iteration 440, loss = 0.17287753
# Iteration 441, loss = 0.17277399
# Iteration 442, loss = 0.17268090
# Iteration 443, loss = 0.17259097
# Iteration 444, loss = 0.17248910
# Iteration 445, loss = 0.17240128
# Iteration 446, loss = 0.17230729
# Iteration 447, loss = 0.17221140
# Iteration 448, loss = 0.17211659
# Iteration 449, loss = 0.17202532
# Iteration 450, loss = 0.17193317
# Iteration 451, loss = 0.17184438
# Iteration 452, loss = 0.17175058
# Iteration 453, loss = 0.17166643
# Iteration 454, loss = 0.17157104
# Iteration 455, loss = 0.17147614
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# dict_keys(['cv', 'error_score', 'estimator__activation', 'estimator__alpha', 'estimator__batch_size', 'estimator__beta_1', 'estimator__beta_2', 'estimator__early_stopping', 'estimator__epsilon', 'estimator__hidden_layer_sizes', 'estimator__learning_rate', 'estimator__learning_rate_init', 'estimator__max_iter', 'estimator__momentum', 'estimator__n_iter_no_change', 'estimator__nesterovs_momentum', 'estimator__power_t', 'estimator__random_state', 'estimator__shuffle', 'estimator__solver', 'estimator__tol', 'estimator__validation_fraction', 'estimator__verbose', 'estimator__warm_start', 'estimator', 'fit_params', 'iid', 'n_jobs', 'param_grid', 'pre_dispatch', 'refit', 'return_train_score', 'scoring', 'verbose'])
# {'hidden_layer_sizes': (50,), 'max_iter': 1000, 'solver': 'sgd', 'verbose': True}

# %%
'''
y_predict = estimator.best_estimator_.predict(X_test)
#y_predict
ann_fileName = "ANN_best"+object_user+"_Hawkes_pred.txt"
np.savetxt(ann_fileName, np.array(y_predict))
'''

# %%
from numpy.random import seed
seed(1)
tf.random.set_seed(2)

# two-layer neural network 
# train part
import numpy as np
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import KFold
from joblib import dump

#neural network classifier of structure (3,2)
kf = KFold(n_splits=4) # 3-fold cross-validation
best_clf = None
best_score = 0
train_scores = []
test_scores = []
print("kfold-------")
for train_index, test_index in kf.split(X_train):
    # create neural network using MLPClassifer  {sgd,lbfgs, adam}
    clf = MLPClassifier(solver = 'sgd', max_iter = 1000, hidden_layer_sizes = (50,),random_state = 1)
    #X_train, X_test = X[train_index], X[test_index]
    #y_train, y_test = y[train_index], y[test_index]
    clf.fit(X_train, y_train)
    train_score = clf.score(X_train, y_train)
    train_scores.append(train_score)
 
    test_score = clf.score(X_test, y_test)
    test_scores.append(test_score)

    #compare score of the tree models and get the best one
    if test_score > best_score:
        best_score = test_score
        best_clf = clf
    
    #print(clf.n_outputs_)
in_sample_error = [1 - score for score in train_scores]
test_set_error = [1 - score for score in test_scores]
print("in_sample_error: ")
print(in_sample_error)
print("test_set_error: ")
print(test_set_error)

#store the classifier
if best_clf != None:
    dump(best_clf, "train_model.m")
    
from joblib import load
clf = load("train_model.m")
y_pred = clf.predict(X_test)
np.savetxt("label_pred.txt", np.array(y_pred)) #save predict result
#print(y_pred)
test_score = clf.score(X_test, y_test)
test_error = 1 - test_score
print('test_score：%s' % test_score)
print('test_error：%s' % test_error)
# Out:
# kfold-------
# in_sample_error:
# [0.057499999999999996, 0.057499999999999996, 0.057499999999999996, 0.057499999999999996]
# test_set_error:
# [0.39749999999999996, 0.39749999999999996, 0.39749999999999996, 0.39749999999999996]
# test_score：0.6025
# test_error：0.39749999999999996

# %%
#评价指标
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score,accuracy_score

y_true = np.reshape(y_test, [-1])
y_pred = np.reshape(y_pred, [-1])
  
# 评价指标
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred, average='binary')
f1score = f1_score(y_true, y_pred, average='binary')
  
# Micro F1: 将n分类的评价拆成n个二分类的评价，将n个二分类评价的TP、FP、RN对应相加，计算评价准确率和召回率，由这2个准确率和召回率计算的F1 score即为Micro F1。
# Macro F1: 将n分类的评价拆成n个二分类的评价，计算每个二分类的F1 score，n个F1 score的平均值即为Macro F1。
# 一般来讲，Macro F1、Micro F1高的分类效果好。Macro F1受样本数量少的类别影响大。
micro_f1 = f1_score(y_true, y_pred,average='micro')
macro_f1 = f1_score(y_true, y_pred,average='macro')
  
print('accuracy:',accuracy)
print('precision:',precision)
print('recall:',recall)
print('f1score:',f1score)
print('Macro-F1: {}'.format(macro_f1))
print('Micro-F1: {}'.format(micro_f1))
# Out:
# accuracy: 0.6025
# precision: 0.22885572139303484
# recall: 0.92
# f1score: 0.36653386454183273
# Macro-F1: 0.5384581891015174
# Micro-F1: 0.6025

# %%
ann_fileName = "ANN_"+object_user+"_Hawkes_pred_final_rep50.txt"
np.savetxt(ann_fileName, np.array(y_pred))
