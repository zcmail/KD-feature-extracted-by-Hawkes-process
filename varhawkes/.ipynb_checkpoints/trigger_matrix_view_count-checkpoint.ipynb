# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import pyplot
import pandas as pd
import numpy as np

fileName1 = './data/CMU_exp_shrink_output_zero.xls'
df_ora = pd.read_excel(fileName1)

np.set_printoptions(threshold=np.inf)

mu_features = [column for column in df_ora.columns if 'mu' in column]
adj_features = [column for column in df_ora.columns if 'adj' in column]
df_mu = df_ora[mu_features]
df_adj = df_ora[adj_features]

names = locals()

x = [i for i in range(2000)]
for i in range(8):
    names['mu' + str(i)] = df_mu.iloc[:,[i]]
    
for i in range(30):
    names['adj' + str(i)]= df_adj.iloc[:,[i]]
    
xticks = [i*100 for i in range(20)]
# Out:
# c:\users\jw\anaconda3\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# c:\users\jw\anaconda3\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# c:\users\jw\anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature mu0')
plt.grid()
plt.plot(x,mu0)
plt.savefig('mu0.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature mu1')
plt.grid()
plt.plot(x,mu1)
plt.savefig('mu1.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature mu2')
plt.grid()
plt.plot(x,mu2)
plt.savefig('mu2.png')

# %%
a = np.array(mu2[1600:1800]).tolist()
sum(i[0] > 0 for i in a )
# Out:
# 135

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature mu3')
plt.grid()
plt.plot(x,mu3)
plt.savefig('mu3.png')

# %%
a = np.array(mu3[400:600]).tolist()
sum(i[0] > 0 for i in a )
# Out:
# 7

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature mu4')
plt.grid()
plt.plot(x,mu4)
plt.savefig('mu4.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature mu5')
plt.grid()
plt.plot(x,mu5)
plt.savefig('mu5.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature mu6')
plt.grid()
plt.plot(x,mu6)
plt.savefig('mu6.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature mu7')
plt.grid()
plt.plot(x,mu7)
plt.savefig('mu7.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_0_0')
plt.grid()
plt.plot(x,adj0)
plt.savefig('adj_0_0.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_1_0')
plt.grid()
plt.plot(x,adj1)
plt.savefig('adj_1_0.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_1_1')
plt.grid()
plt.plot(x,adj2)

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_2_0')
plt.grid()
plt.plot(x,adj3)
plt.savefig('adj_2_0.png')

# %%
a = np.array(adj3[1600:1800]).tolist()
sum(i[0] > 0 for i in a )

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_2_1')
plt.grid()
plt.plot(x,adj4)
plt.savefig('adj_2_1.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_2_2')
plt.grid()
plt.plot(x,adj5)

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_3_1')
plt.grid()
plt.plot(x,adj6)
plt.savefig('adj_3_1.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_3_2')
plt.grid()
plt.plot(x,adj7)
plt.savefig('adj_3_2.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_3_3')
plt.grid()
plt.plot(x,adj8)

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_4_2')
plt.grid()
plt.plot(x,adj9)
plt.savefig('adj_4_2.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_4_3')
plt.grid()
plt.plot(x,adj10)
plt.savefig('adj_4_3.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_4_4')
plt.grid()
plt.plot(x,adj11)

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_5_3')
plt.grid()
plt.plot(x,adj12)
plt.savefig('adj_5_3.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_5_4')
plt.grid()
plt.plot(x,adj13)
plt.savefig('adj_5_4.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_5_5')
plt.grid()
plt.plot(x,adj14)

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_6_4')
plt.grid()
plt.plot(x,adj15)
plt.savefig('adj_6_4.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_6_5')
plt.grid()
plt.plot(x,adj16)
plt.savefig('adj_6_5.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_6_6')
plt.grid()
plt.plot(x,adj17)

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_7_5')
plt.grid()
plt.plot(x,adj18)
plt.savefig('adj_7_5.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_7_6')
plt.grid()
plt.plot(x,adj19)
plt.savefig('adj_7_6.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_7_7')
plt.grid()
plt.plot(x,adj20)

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_8_6')
plt.grid()
plt.plot(x,adj21)
plt.savefig('adj_8_6.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_8_7')
plt.grid()
plt.plot(x,adj22)
plt.savefig('adj_8_7.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_8_8')
plt.grid()
plt.plot(x,adj23)

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_9_7')
plt.grid()
plt.plot(x,adj24)
plt.savefig('adj_9_7.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_9_8')
plt.grid()
plt.plot(x,adj25)
plt.savefig('adj_9_8.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_9_9')
plt.grid()
plt.plot(x,adj26)

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_10_8')
plt.grid()
plt.plot(x,adj27)
plt.savefig('adj_10_8.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_10_9')
plt.grid()
plt.plot(x,adj28)
plt.savefig('adj_10_9.png')

# %%
plt.figure(figsize=(20, 4))
plt.xticks(xticks, size=14)
plt.xlabel('sample')
plt.ylabel('density')
plt.title('Hawkes feature adj_10_10')
plt.grid()
plt.plot(x,adj29)
plt.savefig('adj_10_10.png')
