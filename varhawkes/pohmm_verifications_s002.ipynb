# %%
import pandas as pd
import numpy as np
#from sklearn.preprocessing import StandardScaler,RobustScaler,MinMaxScaler

np.set_printoptions(threshold=np.inf)

#数据准备
fileName = 's002_200train_verification_results_out.csv'
df = pd.read_csv(fileName)
#正测试样本
df_positive = df[0:200]
#负测试样本
df_negative1 = df[200+(26-1)*350:200+26*350]  #s032
df_negative2 = df[200+(30-1)*350:200+30*350]  #s036
df_negative3 = df[200+(40-1)*350:200+40*350]  #s047
df_negative4 = df[200+(45-1)*350:200+45*350]  #s052
df_negative = df_negative1.append([df_negative2,df_negative3,df_negative4])

# %%
y_true = [1]*200+[0]*1400
y_predict = df_positive['score'].tolist() + df_negative['score'].tolist()

# %%
# -*- coding: utf-8 -*-
import matplotlib.pyplot as plt
#from sklearn import svm
from sklearn.metrics import roc_curve, auc  ###计算roc和auc
#import numpy as np
#import random

object_user = 's002'

fpr, tpr, threshold = roc_curve(y_true, y_predict)  ###计算真正率和假正率
roc_auc = auc(fpr, tpr)  ###计算auc的值
 
 
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='darkorange', ###假正率为横坐标，真正率为纵坐标做曲线
         lw=2, label='POHMM (area = %0.3f)' % roc_auc, linestyle='-')

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
#plt.xlim([-0.02, 1.05])#横竖增加一点长度 以便更好观察图像
#plt.ylim([-0.02, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('different feature comparison of '+object_user)
plt.legend(loc="lower right")
save_file = object_user+'POHMM_200samples.png'
plt.savefig(save_file,dpi=600)#保存图片，dpi设置分辨率
plt.show()

# %%
# -*- coding: utf-8 -*-
import matplotlib.pyplot as plt
#from sklearn import svm
from sklearn.metrics import roc_curve, auc  ###计算roc和auc
#import numpy as np
#import random

object_user = 's002'

fpr, tpr, threshold = roc_curve(y_true, y_predict)  ###计算真正率和假正率
roc_auc = auc(fpr, tpr)  ###计算auc的值
 
 
plt.figure(figsize=(8, 8))
plt.plot(fpr, 1- tpr, color='darkorange', ###假正率为横坐标，真正率为纵坐标做曲线
         lw=2, label='POHMM (area = %0.3f)' % roc_auc, linestyle='-')

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
#plt.xlim([-0.02, 1.05])#横竖增加一点长度 以便更好观察图像
#plt.ylim([-0.02, 1.05])
plt.xlabel('False Acceptance Rate')
plt.ylabel('False Rejection Rate')
plt.title('different feature comparison of '+object_user)
plt.legend(loc="lower right")
save_file = object_user+'POHMM_200samples_EER.png'
plt.savefig(save_file,dpi=600)#保存图片，dpi设置分辨率
plt.show()

# %%
fileName2 = 'DSL-StrongPasswordData.xls'
df_oral = pd.read_excel(fileName2)

# %%
df_oral['subject'].unique()
# Out:
# array(['s002', 's003', 's004', 's005', 's007', 's008', 's010', 's011',
#        's012', 's013', 's015', 's016', 's017', 's018', 's019', 's020',
#        's021', 's022', 's024', 's025', 's026', 's027', 's028', 's029',
#        's030', 's031', 's032', 's033', 's034', 's035', 's036', 's037',
#        's038', 's039', 's040', 's041', 's042', 's043', 's044', 's046',
#        's047', 's048', 's049', 's050', 's051', 's052', 's053', 's054',
#        's055', 's056', 's057'], dtype=object)

# %%
#s032是第26个（从0开始计）， 样本的起始index 为 200+(26-1)*350
#s036是第30个， 样本的起始index 为 200+（30-1）*350
#s047是第40个， 样本的起始index 为 200+（40-1）*350
#s052是第45个， 样本的起始index 为 200+（45-1）*350
